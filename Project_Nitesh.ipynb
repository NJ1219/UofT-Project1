# %%
import pandas as pd
import numpy as np
from pyvalet import ValetInterpreter
import datetime as dt
vi = ValetInterpreter()

# %%
# start_date=2013-05-09 & end_date=2020-07-12,
df = vi.get_group_observations("GBPP_RESULTS", response_format='csv')
df.tail()
# Out:
#                     \ngbpp_id" GBPP_AUCTION_DATE  GBPP_TOTAL_AMOUNT  \
# 665  2020-04-01_1_CA135087J546        2020-04-01                NaN
# 666  2020-04-01_1_CA135087B451        2020-04-01                NaN
# 667  2020-04-01_1_CA135087J967        2020-04-01                NaN
# 668  2020-04-01_1_CA135087D507        2020-04-01                NaN
# 669  2020-04-01_1_CA135087VH40        2020-04-01                NaN
#
#     GBPP_SETTLEMENT_DATE GBPP_MATURITY_DATE  GBPP_COUPON_RATE     GBPP_ISIN  \
# 665           2020-04-06         2024-03-01              2.25  CA135087J546
# 666           2020-04-06         2024-06-01              2.50  CA135087B451
# 667           2020-04-06         2024-09-01              1.50  CA135087J967
# 668           2020-04-06         2025-06-01              2.25  CA135087D507
# 669           2020-04-06         2025-06-01              9.00  CA135087VH40
#
#      GBPP_AUCTION_TYPE_VALUE GBPP_AUCTION_TYPE  GBPP_TOTAL_AMOUNT_PURCHASED  \
# ...

# %%
gbpp_df = df[["GBPP_AUCTION_DATE", "GBPP_TOTAL_AMOUNT_PURCHASED"]]
gbpp_df["GBPP_AUCTION_DATE"] = pd.to_datetime(gbpp_df["GBPP_AUCTION_DATE"])
gbpp_df1 = gbpp_df.set_index("GBPP_AUCTION_DATE")
gbpp_df1.head()
# Out:
# C:\Users\nites\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    GBPP_TOTAL_AMOUNT_PURCHASED
# GBPP_AUCTION_DATE
# 2020-07-22                        2.200000e+09
# 2020-07-22                                 NaN
# 2020-07-22                                 NaN
# 2020-07-22                                 NaN
# 2020-07-22                                 NaN

# %%
gbpp_df1.drop(level=1).dropna(inplace=True)
gbpp_df1.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0080344cf18b> in <module>
# ----> 1 gbpp_df1.drop(level=1).dropna(inplace=True)
#       2 gbpp_df1.head()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3771             axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    3772         else:
# ...

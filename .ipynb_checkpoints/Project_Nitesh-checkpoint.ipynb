# %%
import pandas as pd
import numpy as np
from pyvalet import ValetInterpreter
import datetime as dt
vi = ValetInterpreter()

# %%
# start_date=2013-05-09 & end_date=2020-07-12,
# GoC Bond Purchase program
df = vi.get_group_observations("GBPP", response_format='csv')
df.tail()

#GoC mortgage bonds
df1 = vi.get_group_observations("CANADA_MORTGAGE_BOND", response_format='csv')
df1.tail()

#GoC provincial bonds compared to corporate bonds and GoC bonds
df2 = vi.get_group_observations("SAN_BEDP20180709_C1", response_format='csv')
df2

#Canada overnight repo rate average
df3 = vi.get_group_observations("CORRA_GRAPH", response_format='csv')
df3.set_index("date")
# Out:
#          \ndate"  AVG.INTWO  CORRA_TRIMMED_VOLUME
# 0     1997-08-12     3.2500                   NaN
# 1     1997-08-18     3.3000                   NaN
# 2     1997-08-19     3.2600                   NaN
# 3     1997-08-20     3.3450                   NaN
# 4     1997-08-21     3.3850                   NaN
# 5     1997-08-22     3.2650                   NaN
# 6     1997-08-25     3.3360                   NaN
# 7     1997-08-26     3.2670                   NaN
# 8     1997-08-27     3.3070                   NaN
# 9     1997-08-28     3.4615                   NaN
# 10    1997-09-02     3.4426                   NaN
# 11    1997-09-03     3.2820                   NaN
# 12    1997-09-04     3.3477                   NaN
# 13    1997-09-05     3.2500                   NaN
# 14    1997-09-08     3.2702                   NaN
# 15    1997-09-09     3.2890                   NaN
# 16    1997-09-10     3.2730                   NaN
# 17    1997-09-11     3.3400                   NaN
# ...

# %%
gbpp_df = df[["GBPP_AUCTION_DATE", "GBPP_TOTAL_AMOUNT_PURCHASED"]]
gbpp_df["GBPP_AUCTION_DATE"] = pd.to_datetime(gbpp_df["GBPP_AUCTION_DATE"])
gbpp_df1 = gbpp_df.set_index("GBPP_AUCTION_DATE")
gbpp_df1.tail()

corra_graph = df3.hvplot.line()
# Out:
# C:\Users\nites\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-cddae6df0ac7> in <module>
#       4 gbpp_df1.tail()
#       5
# ----> 6 corra_graph = df3.hvplot.line()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# ...

# %%
gbpp_df1.drop(level=1).dropna(inplace=True)
gbpp_df1.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0080344cf18b> in <module>
# ----> 1 gbpp_df1.drop(level=1).dropna(inplace=True)
#       2 gbpp_df1.head()
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3771             axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    3772         else:
# ...

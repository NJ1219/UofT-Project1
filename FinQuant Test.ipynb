# %%
from finquant.portfolio import build_portfolio
import quandl
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\amuni\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
from finquant.portfolio import build_portfolio
names = ['TD.TO', 'CM.TO','BNS.TO','BMO.TO', 'NA.TO','RY.TO']
big_banks_1 = build_portfolio(names=names, data_api="yfinance",start_date="2000-01-01",end_date="2020-01-01")
big_banks_2 = build_portfolio(names=names, data_api="yfinance",start_date="2000-01-01",end_date="2020-03-23")
big_banks_3 = build_portfolio(names=names, data_api="yfinance",start_date="2000-01-01",end_date="2020-06-30")
names2=['FN.TO', 'LB.TO','HCG.TO','EQB.TO']
small_banks_1 = build_portfolio(names=names2, data_api="yfinance",start_date="2000-01-01",end_date="2020-01-01")
small_banks_2 = build_portfolio(names=names2, data_api="yfinance",start_date="2000-01-01",end_date="2020-03-23")
small_banks_3 = build_portfolio(names=names2, data_api="yfinance",start_date="2000-01-01",end_date="2020-06-30")
# Out:
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  4 of 4 completed

# %%
big_banks_1.ef_plot_efrontier()
big_banks_1.ef.plot_optimal_portfolios()
big_banks_1.plot_stocks()
big_banks_1.ef_maximum_sharpe_ratio(verbose=True)
big_banks_1.ef_minimum_volatility(verbose=True)
# Out:
# ----------------------------------------------------------------------
# Optimised portfolio for Maximum Sharpe Ratio
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.165
# Annual Volatility: 0.194
# Sharpe Ratio: 0.823
#
# Optimal weights:
#             TD.TO         CM.TO   BNS.TO   BMO.TO     NA.TO     RY.TO
# Allocation    0.0  2.993009e-17  0.02359  0.04039  0.594988  0.341032
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Optimised portfolio for Minimum Volatility
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.148
# Annual Volatility: 0.185
# Sharpe Ratio: 0.774
#
# Optimal weights:
#                TD.TO     CM.TO    BNS.TO    BMO.TO     NA.TO   RY.TO
# Allocation  0.185197  0.031818  0.151401  0.194447  0.292637  0.1445
# ----------------------------------------------------------------------
# ...

# %%
big_banks_2.ef_plot_efrontier()
big_banks_2.ef.plot_optimal_portfolios()
big_banks_2.plot_stocks()
big_banks_2.ef_maximum_sharpe_ratio(verbose=True)
big_banks_2.ef_minimum_volatility(verbose=True)
# Out:
# ----------------------------------------------------------------------
# Optimised portfolio for Maximum Sharpe Ratio
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.145
# Annual Volatility: 0.204
# Sharpe Ratio: 0.689
#
# Optimal weights:
#                    TD.TO         CM.TO  BNS.TO  BMO.TO     NA.TO     RY.TO
# Allocation  9.914771e-18  7.266807e-17     0.0     0.0  0.526331  0.473669
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Optimised portfolio for Minimum Volatility
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.130
# Annual Volatility: 0.195
# Sharpe Ratio: 0.638
#
# Optimal weights:
#                TD.TO     CM.TO    BNS.TO    BMO.TO     NA.TO    RY.TO
# Allocation  0.187909  0.023521  0.153002  0.166086  0.281962  0.18752
# ----------------------------------------------------------------------
# ...

# %%
small_banks_1.ef_plot_efrontier()
small_banks_1.ef.plot_optimal_portfolios()
small_banks_1.plot_stocks()
small_banks_1.ef_maximum_sharpe_ratio(verbose=True)
small_banks_1.ef_minimum_volatility(verbose=True)
# Out:
# ----------------------------------------------------------------------
# Optimised portfolio for Maximum Sharpe Ratio
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.186
# Annual Volatility: 0.195
# Sharpe Ratio: 0.926
#
# Optimal weights:
#                FN.TO     LB.TO    HCG.TO    EQB.TO
# Allocation  0.470991  0.262177  0.060041  0.206791
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Optimised portfolio for Minimum Volatility
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.157
# Annual Volatility: 0.179
# Sharpe Ratio: 0.848
#
# Optimal weights:
#                FN.TO     LB.TO    HCG.TO    EQB.TO
# Allocation  0.233064  0.530367  0.026562  0.210008
# ----------------------------------------------------------------------
#         Allocation
# FN.TO     0.233064
# LB.TO     0.530367
# HCG.TO    0.026562
# ...

# %%
small_banks_2.ef_plot_efrontier()
small_banks_2.ef.plot_optimal_portfolios()
small_banks_2.plot_stocks()
small_banks_2.ef_maximum_sharpe_ratio(verbose=True)
small_banks_2.ef_minimum_volatility(verbose=True)
# Out:
# ----------------------------------------------------------------------
# Optimised portfolio for Maximum Sharpe Ratio
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.149
# Annual Volatility: 0.211
# Sharpe Ratio: 0.683
#
# Optimal weights:
#               FN.TO     LB.TO    HCG.TO   EQB.TO
# Allocation  0.50294  0.270114  0.060776  0.16617
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Optimised portfolio for Minimum Volatility
#
# Time window/frequency: 252
# Risk free rate: 0.005
# Expected annual Return: 0.124
# Annual Volatility: 0.191
# Sharpe Ratio: 0.619
#
# Optimal weights:
#                FN.TO     LB.TO    HCG.TO    EQB.TO
# Allocation  0.213473  0.547162  0.030132  0.209234
# ----------------------------------------------------------------------
#         Allocation
# FN.TO     0.213473
# LB.TO     0.547162
# HCG.TO    0.030132
# ...

# %%
# Monte Carlo optimisation
opt_w, opt_res = big_banks_1.mc_optimisation(num_trials=5000)
big_banks_1.mc_plot_results()
print(opt_w.head())
print(opt_res.head())
# Out:
#                      TD.TO     CM.TO   BNS.TO    BMO.TO     NA.TO     RY.TO
# Min Volatility    0.214695  0.028336  0.13254  0.174921  0.313662  0.135847
# Max Sharpe Ratio  0.030131  0.033515  0.15895  0.109786  0.437001  0.230617
#                   Expected Return  Volatility  Sharpe Ratio
# Min Volatility           0.148587    0.185344      0.774703
# Max Sharpe Ratio         0.156984    0.187906      0.808830

# %%
opt_w, opt_res = big_banks_2.mc_optimisation(num_trials=5000)
big_banks_2.mc_plot_results()
print(opt_w.head())
print(opt_res.head())
# Out:
#                      TD.TO     CM.TO    BNS.TO    BMO.TO     NA.TO     RY.TO
# Min Volatility    0.184724  0.017432  0.110826  0.196013  0.286890  0.204116
# Max Sharpe Ratio  0.008485  0.032169  0.022336  0.119417  0.432195  0.385398
#                   Expected Return  Volatility  Sharpe Ratio
# Min Volatility           0.130075    0.195458      0.639909
# Max Sharpe Ratio         0.139958    0.199405      0.676803

# %%
pf.ef_minimum_volatility(verbose=True)

# %%
pf.ef_minimum_volatility(verbose=True)

# %%
# Monte Carlo optimisation
opt_w, opt_res = pf.mc_optimisation(num_trials=5000)
pf.mc_plot_results()
# minimisation to compute efficient frontier and optimal portfolios along it
pf.ef_plot_efrontier()
pf.ef.plot_optimal_portfolios()
# plotting individual stocks

# %%
opt_res.head()
